# %%
# Load necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [raw]
# STEP 1: Load the Datasets

# %%
customers = pd.read_csv(r'C:\Users\USER\OneDrive\Desktop\My Briefcase\Full stack analyst\Supply Chain Analysis\OList Dataset\olist_customers_dataset.csv')
geolocation = pd.read_csv(r'C:\Users\USER\OneDrive\Desktop\My Briefcase\Full stack analyst\Supply Chain Analysis\OList Dataset\olist_geolocation_dataset.csv')
order_items = pd.read_csv(r'C:\Users\USER\OneDrive\Desktop\My Briefcase\Full stack analyst\Supply Chain Analysis\OList Dataset\olist_order_items_dataset.csv')
order_payments = pd.read_csv(r'C:\Users\USER\OneDrive\Desktop\My Briefcase\Full stack analyst\Supply Chain Analysis\OList Dataset\olist_order_payments_dataset.csv')
order_reviews = pd.read_csv(r'C:\Users\USER\OneDrive\Desktop\My Briefcase\Full stack analyst\Supply Chain Analysis\OList Dataset\olist_order_reviews_dataset.csv')
orders = pd.read_csv(r'C:\Users\USER\OneDrive\Desktop\My Briefcase\Full stack analyst\Supply Chain Analysis\OList Dataset\olist_orders_dataset.csv')
products = pd.read_csv(r'C:\Users\USER\OneDrive\Desktop\My Briefcase\Full stack analyst\Supply Chain Analysis\OList Dataset\olist_products_dataset.csv')
sellers = pd.read_csv(r'C:\Users\USER\OneDrive\Desktop\My Briefcase\Full stack analyst\Supply Chain Analysis\OList Dataset\olist_sellers_dataset.csv')
product_cat_name_trans = pd.read_csv(r'C:\Users\USER\OneDrive\Desktop\My Briefcase\Full stack analyst\Supply Chain Analysis\OList Dataset\product_category_name_translation.csv')

# %% [raw]
# STEP 2: Quick Inspection (Do this for each table)

# %%
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
customers.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
geolocation.head()
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
geolocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [raw]
# STEP 3: Convert Dates (Very Important)

# %%
orders['order_purchase_timestamp'] = pd.to_datetime(orders['order_purchase_timestamp'])
orders['order_approved_at'] = pd.to_datetime(orders['order_approved_at'])
orders['order_delivered_carrier_date'] = pd.to_datetime(orders['order_delivered_carrier_date'])
orders['order_delivered_customer_date'] = pd.to_datetime(orders['order_delivered_customer_date'])
orders['order_estimated_delivery_date'] = pd.to_datetime(orders['order_estimated_delivery_date'])

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
# Convert date to datetime
order_items['shipping_limit_date'] = pd.to_datetime(order_items['shipping_limit_date'])

# %%
order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
order_reviews.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
order_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
# Convert to date
order_reviews['review_creation_date'] = pd.to_datetime(order_reviews['review_creation_date'])
order_reviews['review_answer_timestamp'] = pd.to_datetime(order_reviews['review_answer_timestamp'])

# %%
products.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %%
sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
product_cat_name_trans.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
product_cat_name_trans.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %% [raw]
# STEP 4: Create Key Supply Chain Metric

# %%
# Delivery Time
orders['delivery_time_days'] = (orders['order_delivered_customer_date'] - orders['order_purchase_timestamp']).dt.days

# %%
orders['delivery_time_days'].head()
# Out:
# 0     8.0
# 1    13.0
# 2     9.0
# 3    13.0
# 4     2.0
# Name: delivery_time_days, dtype: float64

# %% [raw]
# STEP 5: Merge Datasets (Core Analysis Table)

# %%
df = orders.merge(order_items, on='order_id')  \
            .merge(customers, on='customer_id') \
            .merge(products, on='product_id') \
            .merge(product_cat_name_trans, on='product_category_name') \
            .merge(sellers, on='seller_id') \
            .merge(order_payments, on='order_id') \
            .merge(order_reviews, on='order_id')

# %%
df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 2    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 3    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 4    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115609 entries, 0 to 115608
# Data columns (total 41 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       115609 non-null  object
#  1   customer_id                    115609 non-null  object
#  2   order_status                   115609 non-null  object
#  3   order_purchase_timestamp       115609 non-null  datetime64[ns]
#  4   order_approved_at              115595 non-null  datetime64[ns]
#  5   order_delivered_carrier_date   114414 non-null  datetime64[ns]
#  6   order_delivered_customer_date  113209 non-null  datetime64[ns]
#  7   order_estimated_delivery_date  115609 non-null  datetime64[ns]
#  8   delivery_time_days             113209 non-null  float64
#  9   order_item_id                  115609 non-null  int64
#  10  product_id                     115609 non-null  object
# ...

# %% [raw]
# PROPER CLEANING OF THE DATASET

# %%
# Drop duplicates
df.shape
# Out:
# (115609, 41)

# %% [raw]
# STEP 1: Handle missing values

# %%
# Step 1: Check missing values (All Tables)
def check_nulls(df, name):
    print(f"\n{name}")
    print(df.isnull().sum())

check_nulls(orders, "Orders")
check_nulls(order_items, "Order Items")
check_nulls(customers, "Customers")
check_nulls(products, "Products")
check_nulls(sellers, "Sellers")
check_nulls(order_payments, "Payments")
check_nulls(order_reviews, "Reviews")
# Out:
# Orders
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# delivery_time_days               2965
# dtype: int64
#
# Order Items
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64
#
# Customers
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64
#
# Products
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# ...

# %% [raw]
# STEP 2: Handle Missing Values (Important Decisions)

# %%
# Delivery date missing - order not delivered yet
df['delivery_time_days'] = (df['order_delivered_customer_date'] - df['order_purchase_timestamp']).dt.days
df['delivery_time_days'].head()
# Don't drop these rows - they represent undelivered/cancelled orders
# Out:
# 0     8.0
# 1     8.0
# 2     8.0
# 3    13.0
# 4     9.0
# Name: delivery_time_days, dtype: float64

# %%
df[['order_delivered_customer_date', 'order_purchase_timestamp']].head(10)
# Out:
#   order_delivered_customer_date order_purchase_timestamp
# 0           2017-10-10 21:25:13      2017-10-02 10:56:33
# 1           2017-10-10 21:25:13      2017-10-02 10:56:33
# 2           2017-10-10 21:25:13      2017-10-02 10:56:33
# 3           2018-08-07 15:27:45      2018-07-24 20:41:37
# 4           2018-08-17 18:06:29      2018-08-08 08:38:49
# 5           2017-12-02 00:28:42      2017-11-18 19:28:06
# 6           2018-02-16 18:17:02      2018-02-13 21:18:39
# 7           2017-07-26 10:57:55      2017-07-09 21:57:05
# 8           2017-05-26 12:55:51      2017-05-16 13:10:30
# 9           2017-02-02 14:08:10      2017-01-23 18:29:09

# %%
df['delivery_time_days'].head()
# Out:
# 0     8.0
# 1     8.0
# 2     8.0
# 3    13.0
# 4     9.0
# Name: delivery_time_days, dtype: float64

# %%
# Fill the blank product category column
df.fillna({'product_category_name': 'unknown'}, inplace=True)

# %%
df['product_category_name'].isnull().sum()
# Out:
# 0

# %%
# Fill the blank 'Reviews' column

df['review_comment_message'].isnull().sum()
# Out:
# 66703

# %%
df.fillna({'review_comment_title': 'no title'}, inplace=True)

# %%
df.fillna({'review_comment_message': 'no comment'}, inplace=True)

# %%
df['review_comment_message'].isnull().sum()
# Out:
# 0

# %%
df['review_score'].isnull().sum()
# Out:
# 0

# %% [raw]
# STEP 3: Check duplicates

# %%
df['order_id'].duplicated().sum()
# Out:
# 19093

# %%
# Check if there are blanks in the payment related columns to be fixed
df[['payment_sequential', 'payment_type', 'payment_installments']].isnull().sum()
# Out:
# payment_sequential      0
# payment_type            0
# payment_installments    0
# dtype: int64

# %% [raw]
# STEP 5: Handle outliers (Very Important)

# %%
df['delivery_time_days'].describe()
# Out:
# count    113209.000000
# mean         11.976866
# std           9.362238
# min           0.000000
# 25%           6.000000
# 50%          10.000000
# 75%          15.000000
# max         208.000000
# Name: delivery_time_days, dtype: float64

# %% [raw]
# STEP 6: Create Useful Columns (Add Value)

# %%
df['order_month'] = df['order_purchase_timestamp'].dt.to_period('M')
df['order_day'] = df['order_purchase_timestamp'].dt.day_name()
df[['order_month', 'order_day']].head()
# Out:
#   order_month  order_day
# 0     2017-10     Monday
# 1     2017-10     Monday
# 2     2017-10     Monday
# 3     2018-07    Tuesday
# 4     2018-08  Wednesday

# %%
df.to_csv(r'C:\Users\USER\OneDrive\Desktop\My Briefcase\Full stack analyst\Supply Chain Analysis\OList Dataset\cleaned_joined_olist_dataset.csv')

# %% [raw]
# ANALYSIS

# %% [raw]
# STEP 1: Core KPIs

# %%
# Average delivery time
avg_delivery_time = df['delivery_time_days'].mean()
avg_delivery_time
# Out:
# 11.97686579688894

# %%
# Total order
total_order = df['order_id'].nunique()
total_order
# Out:
# 96516

# %%
# total revenue
total_revenue = df['payment_value'].sum()
total_revenue
# Out:
# 19929532.499999996

# %%
df[['order_status', 'price', 'product_category_name_english', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value']].head(20)
# Out:
#    order_status   price product_category_name_english  payment_sequential  \
# 0     delivered   29.99                    housewares                   1
# 1     delivered   29.99                    housewares                   3
# 2     delivered   29.99                    housewares                   2
# 3     delivered  118.70                     perfumery                   1
# 4     delivered  159.90                          auto                   1
# 5     delivered   45.00                      pet_shop                   1
# 6     delivered   19.90                    stationery                   1
# 7     delivered  147.90                          auto                   1
# 8     delivered   59.99                          auto                   1
# 9     delivered   19.90               furniture_decor                   1
# 10    delivered  149.99              office_furniture                   2
# 11    delivered  149.99              office_furniture                   1
# ...

# %%
df[['order_id','customer_id', 'order_status', 'price', 'product_category_name_english', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value']].duplicated().sum()
# Out:
# 12075

# %%
df['order_id'].duplicated().sum()
# Out:
# 19093

# %% [raw]
# STEP 2: Delivery Performance

# %%
# Delivered orders
delivered_orders = df['order_delivered_customer_date'].notna()
delivered_orders.sum()
# Out:
# 113209

# %%
delivered_orders.describe()
# Out:
# count     115609
# unique         2
# top         True
# freq      113209
# Name: order_delivered_customer_date, dtype: object

# %%
# Late deliveries
late_delivery = (df['order_delivered_customer_date'] > df['order_estimated_delivery_date'])
late_delivery.value_counts()
# Out:
# False    106894
# True       8715
# Name: count, dtype: int64

# %%
# Late delivery rate (%)
late_rate = late_delivery.mean() * 100
late_rate
# Out:
# 7.538340440623135

# %% [raw]
# STEP 3: Monthly Order Trend

# %%
monthly_orders = df.groupby('order_month') ['order_id'].nunique()
monthly_orders.plot(figsize=(10, 5), title="Montly Order Trend")
plt.show()
# Insight: Growth, seasonality, demand spikes

# %% [raw]
# STEP 4: Top States by Revenue

# %%
top_states = df.groupby('customer_state')['payment_value'].sum().sort_values(ascending=False).head(10)
top_states.plot(kind="bar",figsize = (10,5), title="Top States by Revenue")
plt.show()

# %% [raw]
# STEP 5: Top Product Categories

# %%
top_prod_cat = df.groupby('product_category_name_english')['payment_value'].sum().sort_values(ascending=True).head(10)
top_prod_cat.plot(kind="barh", figsize=(10,5), title="Top Product Categories")
plt.show()

# %% [raw]
# STEP 6: Seller Performance

# %%
# Top Sellers
df.groupby('seller_id')['payment_value'].sum().sort_values(ascending=False).head(10)
# Out:
# seller_id
# 7c67e1448b00f6e969d365cea6b010ab    509474.13
# 1025f0e2d44d7041d6cf58b6550e0bfa    310579.23
# 4a3ca9315b744ce9f8e9374361493884    302403.81
# 1f50f920176fa81dab994f9023523100    290729.12
# 53243585a1d6dc2643021fd1853d8905    282750.15
# da8622b14eb17ae2831f4ac5b9dab84a    275667.80
# 4869f7a5dfa277a7dca6462dcf3b52b2    262628.03
# 955fee9216a65b617aa5c0531780ce60    234603.88
# fa1c13f2614d7b5c4749cbc52fecda94    205173.24
# 7e93a43ef30c4f03f38b393420bc753a    184867.29
# Name: payment_value, dtype: float64

# %%
# Fastest Sellers (Delivery Speed)
df.groupby('seller_id')['delivery_time_days'].mean().sort_values().head(10)
# Out:
# seller_id
# 674207551483fec113276b67b0d871ff    1.0
# 751e274377499a8503fd6243ad9c56f6    1.0
# 139157dd4daa45c25b0807ffff348363    1.0
# 5e063e85d44b0f5c3e6ec3131103a57e    1.0
# c04d70d515d15a7e3db3a73320598566    1.0
# 96f7c797de9ca20efbe14545bed63eec    1.0
# f3511c85f59f8dec53d140501ee8e7a8    1.0
# 6561d6bf844e464b4019442692b40e02    1.0
# 2c00c85d30361cd2ced2969cffbbffa3    1.0
# 734def04b237117a09321dd6d8f3f2a2    1.5
# Name: delivery_time_days, dtype: float64

# %% [raw]
# STEP 7: Payment Behaviour

# %%
payment_type = df['payment_type'].value_counts().sort_values(ascending=False)
payment_type.plot(kind='pie', figsize=(10,5), title="Payment Types")
plt.show()

# %% [raw]
# STEP 8: Review vs Delivery Insight (Important)

# %%
rev_del = df.groupby('review_score')['delivery_time_days'].mean()
rev_del.plot(kind="bar", figsize=(10,5), title="Review Score vs Delivery Time (In Days)")
plt.show()
# Insight: Longer delivery, lower review score (usually)

# %%
kpis = {
    "Total Orders": df['order_id'].nunique(),
    "Total Revenue": df['payment_value'].sum(),
    "Avg Delivery Time (days)": df['delivery_time_days'].mean(),
    "Late Delivery Rate (%)": late_rate
}

kpis
# Out:
# {'Total Orders': 96516,
#  'Total Revenue': 19929532.499999996,
#  'Avg Delivery Time (days)': 11.97686579688894,
#  'Late Delivery Rate (%)': 7.538340440623135}

# %% [raw]
# REVENUE OVER TIME (Trend)

# %%
revenue_trend = df.groupby('order_month')['payment_value'].sum()
revenue_trend.plot(figsize=(10, 5), title="Monthly Revenue Trend")
plt.show()
# Growth? Decline? Spikes? e.g festive periods

# %% [raw]
# Order vs Delivery Time

# %%
monthly_delivery = df.groupby('order_month')['delivery_time_days'].mean()
monthly_delivery.plot(figsize=(10,5), title="Avg Delivery Time Trend")
plt.show()
# If delivery time increase when orders increase = logistic strain

# %% [raw]
# Late Delivery Deep Dive

# %%
df['late_delivery'] = (df['order_delivered_customer_date'] > df['order_estimated_delivery_date'])
df['late_delivery'].value_counts()
               
late_by_state = df.groupby('customer_state')['late_delivery'].mean().sort_values(ascending=False).head()
late_by_state.plot(kind='bar', figsize=(10,5), title="Late Delivery by State")
plt.show()

# %%
# Late delivery by seller
late_by_seller = df.groupby('seller_id')['late_delivery'].mean().sort_values(ascending=False).head(10)
#late_by_seller.plot(figsize=(10, 5), title="Late Delivery by Seller")
#plt.show()
late_by_seller
# Out:
# seller_id
# fb8904a8ea99f8831b64ce27db2c1765    1.0
# 51a04a8a6bdcb23deccc82b0b80742cf    1.0
# 63704069d9bd3a75c1cf59babe56004a    1.0
# 1b4b28463457a256e9a784ebe2a8f630    1.0
# df683dfda87bf71ac3fc63063fba369d    1.0
# 9da15f4a4ea758d9eeb49000dbe57e22    1.0
# 271b8923c6a549e02d3c9fd1f8c0422b    1.0
# c13ef0cfbe42f190780f621ce81f2234    1.0
# b8d890108a7a80e4f5d59eea9f362438    1.0
# da2782c804606d2a5d8e1760dbb3e7ec    1.0
# Name: late_delivery, dtype: float64

# %% [raw]
# Customer Experience Insight (Very Powerful)

# %%
review_delivery = df.groupby('review_score')['delivery_time_days'].mean()
review_delivery
# Customers who waited longer gave lower ratings
# Out:
# review_score
# 1    19.139759
# 2    15.301302
# 3    13.565974
# 4    11.780345
# 5    10.199850
# Name: delivery_time_days, dtype: float64

# %% [raw]
# Basket Size (Advanced Insight)

# %%
basket = df.groupby('order_id')['payment_value'].sum()
basket.describe()
# Shows average order value (AOV)
# Out:
# count     96516.000000
# mean        206.489416
# std         610.004112
# min           9.590000
# 25%          62.980000
# 50%         109.910000
# 75%         196.920000
# max      109312.640000
# Name: payment_value, dtype: float64
